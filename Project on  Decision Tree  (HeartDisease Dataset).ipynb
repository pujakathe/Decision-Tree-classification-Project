# %% [markdown]
# ## Project on Decision Tree

# %%
import os
os.chdir("C:/Users/Pooja Kathe/Desktop/linear_regression dataset/HeartDiseasePrediction/Heart Disease Prediction/Dataset")
import pandas as pd

df=pd.read_csv("HeartDisease.csv")

# %%
df
# Out:
#      age  gender  chest_pain  rest_bps  cholestrol  fasting_blood_sugar  \
# 0     63       1           3       145         233                    1
# 1     37       1           2       130         250                    0
# 2     41       0           1       130         204                    0
# 3     56       1           1       120         236                    0
# 4     57       0           0       120         354                    0
# ..   ...     ...         ...       ...         ...                  ...
# 298   57       0           0       140         241                    0
# 299   45       1           3       110         264                    0
# 300   68       1           0       144         193                    1
# 301   57       1           0       130         131                    0
# 302   57       0           1       130         236                    0
#
#      rest_ecg  thalach  exer_angina  old_peak  slope  ca  thalassemia  target
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  303 non-null    int64
#  1   gender               303 non-null    int64
#  2   chest_pain           303 non-null    int64
#  3   rest_bps             303 non-null    int64
#  4   cholestrol           303 non-null    int64
#  5   fasting_blood_sugar  303 non-null    int64
#  6   rest_ecg             303 non-null    int64
#  7   thalach              303 non-null    int64
#  8   exer_angina          303 non-null    int64
#  9   old_peak             303 non-null    float64
#  10  slope                303 non-null    int64
#  11  ca                   303 non-null    int64
#  12  thalassemia          303 non-null    int64
#  13  target               303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
df.shape
# Out:
# (303, 14)

# %%
df.isna().sum()
# Out:
# age                    0
# gender                 0
# chest_pain             0
# rest_bps               0
# cholestrol             0
# fasting_blood_sugar    0
# rest_ecg               0
# thalach                0
# exer_angina            0
# old_peak               0
# slope                  0
# ca                     0
# thalassemia            0
# target                 0
# dtype: int64

# %%
df.describe()
# Out:
#               age      gender  chest_pain    rest_bps  cholestrol  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026
# std      9.082101    0.466011    1.032052   17.538143   51.830751
# min     29.000000    0.000000    0.000000   94.000000  126.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000
# max     77.000000    1.000000    3.000000  200.000000  564.000000
#
#        fasting_blood_sugar    rest_ecg     thalach  exer_angina    old_peak  \
# count           303.000000  303.000000  303.000000   303.000000  303.000000
# mean              0.148515    0.528053  149.646865     0.326733    1.039604
# std               0.356198    0.525860   22.905161     0.469794    1.161075
# ...

# %%
df.columns
# Out:
# Index(['age', 'gender', 'chest_pain', 'rest_bps', 'cholestrol',
#        'fasting_blood_sugar', 'rest_ecg', 'thalach', 'exer_angina', 'old_peak',
#        'slope', 'ca', 'thalassemia', 'target'],
#       dtype='object')

# %%
df_attr=df[:]

# %%
df_attr.columns
# Out:
# Index(['age', 'gender', 'chest_pain', 'rest_bps', 'cholestrol',
#        'fasting_blood_sugar', 'rest_ecg', 'thalach', 'exer_angina', 'old_peak',
#        'slope', 'ca', 'thalassemia', 'target'],
#       dtype='object')

# %%
df_attr.target=df_attr.target.astype("object")
# Out:
# C:\Users\Pooja Kathe\anaconda3\lib\site-packages\pandas\core\generic.py:5168: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
df_attr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  303 non-null    int64
#  1   gender               303 non-null    int64
#  2   chest_pain           303 non-null    int64
#  3   rest_bps             303 non-null    int64
#  4   cholestrol           303 non-null    int64
#  5   fasting_blood_sugar  303 non-null    int64
#  6   rest_ecg             303 non-null    int64
#  7   thalach              303 non-null    int64
#  8   exer_angina          303 non-null    int64
#  9   old_peak             303 non-null    float64
#  10  slope                303 non-null    int64
#  11  ca                   303 non-null    int64
#  12  thalassemia          303 non-null    int64
#  13  target               303 non-null    object
# dtypes: float64(1), int64(12), object(1)
# memory usage: 33.3+ KB

# %%
df.drop(['target'],axis=1,inplace=True)

# %%
import numpy as np

# %%
df_num=df.select_dtypes(include=[np.number])

# %%
df_num.columns
# Out:
# Index(['age', 'gender', 'chest_pain', 'rest_bps', 'cholestrol',
#        'fasting_blood_sugar', 'rest_ecg', 'thalach', 'exer_angina', 'old_peak',
#        'slope', 'ca', 'thalassemia'],
#       dtype='object')

# %%
df_num.head()
# Out:
#    age  gender  chest_pain  rest_bps  cholestrol  fasting_blood_sugar  \
# 0   63       1           3       145         233                    1
# 1   37       1           2       130         250                    0
# 2   41       0           1       130         204                    0
# 3   56       1           1       120         236                    0
# 4   57       0           0       120         354                    0
#
#    rest_ecg  thalach  exer_angina  old_peak  slope  ca  thalassemia
# 0         0      150            0       2.3      0   0            1
# 1         1      187            0       3.5      0   0            2
# 2         0      172            0       1.4      2   0            2
# 3         1      178            0       0.8      2   0            2
# 4         1      163            1       0.6      2   0            2

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
corr1=df_attr.corr()
plt.subplots(figsize=(16,8))
sns.heatmap(corr1,annot=True)
# Out:
# <AxesSubplot:>

# %%
pd.crosstab(df_attr.age,df_attr.target).plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='age'>

# %% [markdown]
# the probability of heart disease in higher in age below 55.and above the age 55 the probability rate in decline

# %%
pd.crosstab(df_attr.gender,df_attr.target).plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='gender'>

# %%
pd.crosstab(df_attr.chest_pain,df_attr.target).plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='chest_pain'>

# %% [markdown]
#  we observed when there is no or less chest_pain(0)then the rate of heart disease is low,when chest_pain(1,2,3) increases the heart disease rate lso increase

# %%
pd.crosstab(df_attr.rest_bps,df_attr.target).plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='rest_bps'>

# %% [markdown]
# in above graph when blood presure level in between 120 to 135 the heart disease rate is high

# %%
pd.crosstab(df_attr.fasting_blood_sugar,df_attr.target).plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='fasting_blood_sugar'>

# %% [markdown]
# when the person have no fast then the the heart disease chances in more

# %%
pd.crosstab(df_attr.rest_ecg,df_attr.target).plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='rest_ecg'>

# %% [markdown]
# when there is Potassium level(1) then heart disease rate is more than the Potassium level(0,2)

# %%
from sklearn.model_selection import train_test_split

# %%
train_x=df_num

# %%
train_y=df_attr["target"]

# %%
X_train,X_test,y_train,y_test=train_test_split(train_x,train_y,test_size=0.3,random_state=20)

# %%
X_train[0:2]
# Out:
#     age  gender  chest_pain  rest_bps  cholestrol  fasting_blood_sugar  \
# 98   43       1           2       130         315                    0
# 73   51       1           0       140         261                    0
#
#     rest_ecg  thalach  exer_angina  old_peak  slope  ca  thalassemia
# 98         1      162            0       1.9      2   1            2
# 73         0      186            1       0.0      2   0            2

# %%
y_train[0:2]
# Out:
# 98    1
# 73    1
# Name: target, dtype: int64

# %% [markdown]
# ### Decision Tree model

# %%
from sklearn import tree

# %%
dt=tree.DecisionTreeClassifier()  ### create model object

# %%
y_train.isna().sum()
# Out:
# 0

# %%
X_train.shape
# Out:
# (212, 13)

# %%
y_train.shape
# Out:
# (212,)

# %%
y_train=y_train.astype(np.number)

# %%
y_train.dtype
# Out:
# dtype('float64')

# %%
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pre=dt.predict(X_test)

# %%
y_pre=y_pre.astype(np.number)
# Out:
# <ipython-input-131-10e3e1fe95ca>:1: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   y_pre=y_pre.astype(np.number)

# %%
y_test=y_test.astype(np.number)

# %%
from sklearn import metrics

# %%
print("Accuracy",metrics.accuracy_score(y_test,y_pre))
# Out:
# Accuracy 0.7912087912087912

# %%
print("precision",metrics.precision_score(y_test,y_pre))
# Out:
# precision 0.851063829787234

# %%
print("Recall",metrics.recall_score(y_test,y_pre))
# Out:
# Recall 0.7692307692307693

# %%
df_attr.target.value_counts()
# Out:
# 1    165
# 0    138
# Name: target, dtype: int64

# %%
import matplotlib.pyplot as plt
from sklearn import tree

# %%
plt.figure(figsize=(20,10))
tree.plot_tree(dt,
               filled=True,rounded=True,feature_names=X_train.columns,class_names=["0","1"],fontsize=12)
plt.show()

# %% [markdown]
# ### Hyperparameter tuning

# %%
from time import time
from scipy.stats import randint as sp_randint
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV

# %%
## create function to generate report
def report(results,n_top=3):
    for i in range(1,n_top+1):
        candidates=np.flatnonzero(results["rank_test_score"]==i)
        for candidate in candidates:
            print("model with rank:{0: .3f} (std: {1: .3f})".format(results["mean_test_score"][candidate],
                                                                   results["std_test_score"][candidate]))
            print("Parameters: {0}" .format(results["params"][candidate]))
            print("")

# %% [markdown]
# ### Randomized Search

# %%
## specipy parameter and distribution to sample fram
param_dist={"max_depth":[5,None],                 
           "max_features":sp_randint(1,13),
           "min_samples_split":sp_randint(2,13),
           "criterion":["gini","entropy"]}

# %%
## run randomized search
n_iter_search=20
random_search=RandomizedSearchCV(dt,param_distributions=param_dist,n_iter=n_iter_search,cv=5)

# %%
start=time()
random_search.fit(X_train,y_train)
print("Randomized search too %.2f second for %d candidates" "parameter setting."%((time()-start),n_iter_search))
report(random_search.cv_results_)
# Out:
# Randomized search too 0.65 second for 20 candidatesparameter setting.
# model with rank: 0.769 (std:  0.037)
# Parameters: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 2, 'min_samples_split': 2}
#
# model with rank: 0.764 (std:  0.027)
# Parameters: {'criterion': 'gini', 'max_depth': 5, 'max_features': 6, 'min_samples_split': 9}
#
# model with rank: 0.764 (std:  0.038)
# Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 6, 'min_samples_split': 9}

# %% [markdown]
# ### Grid search

# %%
## specipy parameter and distribution to sample fram
param_grid={"max_depth":[3,None],                ##try [3,4,5,None] 
           "max_features":[1,3,10],
           "min_samples_split":[2,3,10],
           "criterion":["gini","entropy"]}

# %%
grid_search=GridSearchCV(dt,param_grid=param_grid,cv=5)

# %%
start=time()
grid_search.fit(X_train,y_train)
print("GridSearchCV search took %.2f second for %d candidate" "parameter settings."%((time()-start),
                                                                                     len(grid_search.cv_results_["params"])))
report(grid_search.cv_results_)
# Out:
# GridSearchCV search took 1.12 second for 36 candidateparameter settings.
# model with rank: 0.793 (std:  0.022)
# Parameters: {'criterion': 'gini', 'max_depth': 3, 'max_features': 10, 'min_samples_split': 3}
#
# model with rank: 0.788 (std:  0.046)
# Parameters: {'criterion': 'gini', 'max_depth': 3, 'max_features': 10, 'min_samples_split': 2}
#
# model with rank: 0.778 (std:  0.036)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 10, 'min_samples_split': 3}

# %%
Parameters: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 10, 'min_samples_split': 3}

# %%
dt_grid_search=tree.DecisionTreeClassifier(criterion= 'gini', max_depth=3, max_features= 10, min_samples_split= 10)

# %%
dt_grid_search.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=3, max_features=10, min_samples_split=10)

# %%
y_pred_gs=dt_grid_search.predict(X_test)

# %%
print("Accuracy",metrics.accuracy_score(y_test,y_pred_gs))
print("precision",metrics.precision_score(y_test,y_pred_gs))
print("Recall",metrics.recall_score(y_test,y_pred_gs))
# Out:
# Accuracy 0.8131868131868132
# precision 0.8431372549019608
# Recall 0.8269230769230769

# %%
plt.figure(figsize=(20,10))
tree.plot_tree(dt_grid_search,
               filled=True,rounded=True,
               feature_names=X_train.columns,
               class_names=["0","1"],fontsize=12)
plt.show()

# %% [markdown]
# #### by increasing the hyperparameter

# %%
## specipy parameter and distribution to sample fram
param_dist={"max_depth":[5,None],                ##try [3,4,5,None] 
           "max_features":sp_randint(1,11),
           "min_samples_split":sp_randint(2,11),
            "min_samples_leaf":sp_randint(2,10),
            "max_leaf_nodes":sp_randint(2,10),
           "criterion":["gini","entropy"]}

# %%
grid_search=GridSearchCV(dt,param_grid=param_grid,cv=5)

# %%
start=time()
grid_search.fit(X_train,y_train)
print("GridSearchCV search took %.2f second for %d candidate" "parameter settings."%((time()-start),
                                                                                     len(grid_search.cv_results_["params"])))
report(grid_search.cv_results_)
# Out:
# GridSearchCV search took 1.34 second for 36 candidateparameter settings.
# model with rank: 0.797 (std:  0.043)
# Parameters: {'criterion': 'gini', 'max_depth': 3, 'max_features': 3, 'min_samples_split': 10}
#
# model with rank: 0.788 (std:  0.050)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 3, 'min_samples_split': 10}
#
# model with rank: 0.783 (std:  0.024)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 3, 'min_samples_split': 3}

# %%
Parameters: {'criterion': 'gini', 'max_depth': 3, 'max_features': 3, 'min_samples_split': 10}

# %%
dt_grid_search=tree.DecisionTreeClassifier(criterion= 'gini', max_depth=3, max_features= 3, min_samples_split= 10)

# %%
dt_grid_search.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=3, max_features=3, min_samples_split=10)

# %%
y_pred_gs=dt_grid_search.predict(X_test)

# %%
print("Accuracy",metrics.accuracy_score(y_test,y_pred_gs))
print("precision",metrics.precision_score(y_test,y_pred_gs))
print("Recall",metrics.recall_score(y_test,y_pred_gs))
# Out:
# Accuracy 0.8351648351648352
# precision 0.8490566037735849
# Recall 0.8653846153846154

# %%
plt.figure(figsize=(20,10))
tree.plot_tree(dt_grid_search,
               filled=True,rounded=True,
               feature_names=X_train.columns,
               class_names=["0","1"],fontsize=12)
plt.show()
